# %% [markdown]
# ### WP 1.3.
#
# This is a demo for Fin-Clariah Demo day.
#
# The demo shows how toxicity detection works using Finnish model trained for multi-label text classification.

# %%
# !pip3 install transformers datasets --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 39.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 44.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 27.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 100.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 74.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 34.2 MB/s eta 0:00:00

# %%
import transformers
import datasets
from pprint import pprint

# %%
model = transformers.AutoModelForSequenceClassification.from_pretrained("TurkuNLP/bert-large-finnish-cased-toxicity")
tokenizer = transformers.AutoTokenizer.from_pretrained("TurkuNLP/bert-large-finnish-cased-v1")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/509 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/424k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/815k [00:00<?, ?B/s]

# %%
test_pipe = transformers.pipeline(task="text-classification", model=model, tokenizer=tokenizer, function_to_apply="sigmoid", top_k=None) # return_all_scores=True is deprecated

# %%
# to test what kind of predictions the model will make change the texts in the test variable below
# note that if the probability has too many digits it will default to scientific notation

test = ["Oot ihan nuija.", "Senkin kakkapää", "Tämän pitäisi olla ihan puhdasta tekstiä."]

results = test_pipe(test)

for zipped in zip(test, results):
  pprint(zipped)
# Out:
# ('Oot ihan nuija.',
#  [{'label': 'label_toxicity', 'score': 0.9974742531776428},
#   {'label': 'label_insult', 'score': 0.9962804913520813},
#   {'label': 'label_obscene', 'score': 0.9928241968154907},
#   {'label': 'label_severe_toxicity', 'score': 0.03737211599946022},
#   {'label': 'label_identity_attack', 'score': 0.023151831701397896},
#   {'label': 'label_threat', 'score': 0.0062942043878138065}])
# ('Senkin kakkapää',
#  [{'label': 'label_toxicity', 'score': 0.0894266813993454},
#   {'label': 'label_obscene', 'score': 0.011495253071188927},
#   {'label': 'label_insult', 'score': 0.004559696186333895},
#   {'label': 'label_threat', 'score': 0.002224396215751767},
#   {'label': 'label_identity_attack', 'score': 0.0016641730908304453},
#   {'label': 'label_severe_toxicity', 'score': 0.00021262606605887413}])
# ('Tämän pitäisi olla ihan puhdasta tekstiä.',
#  [{'label': 'label_toxicity', 'score': 0.004279312212020159},
#   {'label': 'label_obscene', 'score': 0.0008480548276565969},
#   {'label': 'label_insult', 'score': 0.0004348654765635729},
#   {'label': 'label_threat', 'score': 0.0002978763950522989},
#   {'label': 'label_identity_attack', 'score': 0.00017777225002646446},
#   {'label': 'label_severe_toxicity', 'score': 9.643987868912518e-05}])
